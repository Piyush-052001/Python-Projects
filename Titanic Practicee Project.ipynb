# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('titanicc.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Display the first few rows of the dataset
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Display the last few rows of the dataset
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# It gives the information or summary of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Get summary statistics of numerical variables
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Check the dimensions of the dataset
df.shape
# Out:
# (891, 12)

# %%
# Check the data types of variables
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# Check for missing values
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Drop the cabin column as it has more null values
df.drop('Cabin',axis =1, inplace =True)

# %%
# Fill missing values with specific values
df['Age'].fillna(np.mean(df.Age), inplace = True)

# %%
# Fill missing values of a specific column using mode 
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'].fillna('S', inplace=True)

# %% [markdown]
# # Bar Graph

# %%
sur = df.Survived.value_counts()
sur
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
plt.bar(sur.index, sur.values, color = ['maroon','yellow'])
plt.xlabel('Survived')
plt.ylabel('Count')
plt.title('Survival Count')
plt.show()

# %% [markdown]
# Bar Graph shows the count of total number of Male and Female Survived

# %%
sib_spo = df.SibSp.value_counts()
sib_spo
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
plt.bar(sib_spo.index, sib_spo.values, color = ['pink','orange','green','blue','maroon','yellow'])
plt.xlabel('Siblings and Spouses')
plt.ylabel('Count')
plt.title('Siblings and Spouses vs Total Count')
plt.show()

# %%
emb = df.Embarked.value_counts()
emb
# Out:
# Embarked
# S    646
# C    168
# Q     77
# Name: count, dtype: int64

# %%
plt.bar(emb.index, emb.values, color = ['red','green','black'])
plt.xlabel('Embarked Class')
plt.ylabel('Number of passengers')
plt.title('Representation of graph on Embarked Column')
plt.show()

# %%
pass_count = df.Sex.value_counts()
pass_count
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
plt.bar(pass_count.index, pass_count.values, color = ['pink', 'yellow'])
plt.xlabel('Gender')
plt.ylabel('Passenger count')
plt.title('Sex Representation')
plt.show()

# %% [markdown]
# # Histogram

# %%
plt.hist(df.Age, bins = 10)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age')
plt.show()

# %%
plt.hist(df.Fare)
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.title('Distribution of Fare')
plt.show()

# %%
df.hist(figsize=(12,12))
plt.show()

# %% [markdown]
# # Pie Chart

# %%
p_class = df.Pclass.value_counts()
p_class
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
plt.pie(p_class.values, labels = p_class.index, autopct ='%1.1f%%', shadow=True, explode=(0.1,0.1,0.1),
       colors = ['red','pink','green'],
       wedgeprops={'edgecolor':'black',
                  'linewidth': 2})
plt.title('Pie chart for PClass')
plt.legend(title = '3 Class')
plt.show()

# %%
count_life = df.Survived.value_counts()
count_life
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
plt.pie(count_life.values, labels = count_life.index, autopct='%1.1f%%', shadow = True, explode = (0.1,0.1), 
        colors =['maroon','orange'], 
        wedgeprops = {'edgecolor' : 'black',
                     'linewidth' : 1.5})
plt.legend()
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
plt.scatter(df.Age, df.Fare, color = 'hotpink')
plt.xlabel('Age of passenger')
plt.ylabel('Fare of Ticket')
plt.title('Age vs Fare')
plt.show()

# %% [markdown]
# # Boxplot

# %%
df.boxplot('Age')
plt.show()

# %%
plt.boxplot(df.Age)
plt.violinplot(df.Age)
plt.show()

# %%
df.boxplot('Fare')
plt.show()

# %%
plt.boxplot(df.Fare)
plt.violinplot(df.Fare)
plt.show()

# %% [markdown]
# # Seaborn

# %%
# Finding how many male and female survived
sns.set_style('whitegrid')
sns.countplot(x = 'Survived' , hue ='Sex', data = df)
plt.show()

# %%
# Finding how many male and female survived from a particular class
sns.set_style('darkgrid')
sns.countplot(x = 'Survived' , hue ='Pclass', data = df)
plt.show()

# %%
sns.boxplot(x = 'Pclass', y = 'Age', data = df)
plt.xlabel("Passenger Class")
plt.ylabel("Age of passengers")
plt.show()

# %%
sns.violinplot(x = 'Pclass', y = 'Age', data = df)
plt.xlabel("Passenger Class")
plt.ylabel("Age of passengers")
plt.show()

# %%
sns.violinplot(x ="Sex", y ="Age", hue ="Survived", 
data = df, split = True)
plt.xlabel("Sex")
plt.ylabel("Age of passengers")
plt.title('Sex and Age vs Survived')
plt.show()

# %%
sns.boxplot(x = 'Survived', y = 'Fare', data = df)
plt.xlabel("Survived")
plt.ylabel("Fare")
plt.show()

# %%
sns.swarmplot(x = 'Pclass', y = 'Age', data = df, hue = 'Pclass')
plt.show()
# Out:
# C:\Users\piyush\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 7.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\piyush\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 30.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\piyush\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 10.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\piyush\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 38.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(df, hue = 'Embarked')\
.map(plt.scatter, 'Age','Fare' )
plt.show()
# Out:
# C:\Users\piyush\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df, hue = 'Pclass')
# Out:
# C:\Users\piyush\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Applying Machine Learning Algorithm

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labels = LabelEncoder()
df['Sex'] = labels.fit_transform(df['Sex'])

# %%
df['Embarked'] = labels.fit_transform(df['Embarked'])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000      1
# 2                               Heikkinen, Miss. Laina    0  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000      1
# 4                             Allen, Mr. William Henry    1  35.000000      0
# ...

# %%
#Splitting data in input and output
x = df[['Pclass','Sex','Age']]
y = df['Survived']

# %%
#Splitting data into train and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %%
#Applying Logistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
model = LogisticRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
acc_score = accuracy_score(y_test, y_pred)*100
acc_score
# Out:
# 78.77094972067039

# %%
accuracies = []
accuracies.append(acc_score)

# %%
#Applying Decision Tree
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
acc_score = accuracy_score(y_test, y_pred)*100
acc_score
# Out:
# 79.88826815642457

# %%
accuracies.append(acc_score)

# %%
#Applying Support Vector Machine(SVM)
from sklearn.svm import SVC
model = SVC()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
acc_score = accuracy_score(y_test, y_pred)*100
acc_score
# Out:
# 63.687150837988824

# %%
accuracies.append(acc_score)

# %%
#Applying KNN
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
acc_score = accuracy_score(y_test, y_pred)*100
acc_score
# Out:
# 72.06703910614524

# %%
accuracies.append(acc_score)

# %%
#Applying Naive Bayes
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
acc_score = accuracy_score(y_test, y_pred)*100
acc_score
# Out:
# 74.30167597765363

# %%
accuracies.append(acc_score)

# %%
#Applying Random Forest
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
acc_score = accuracy_score(y_test, y_pred)*100
acc_score
# Out:
# 79.3296089385475

# %%
accuracies.append(acc_score)

# %%
classifiers = ['Logistic regression','Decision Tree','SVM', 'KNN','Naive Bayes','Random Forest']

# %%
plt.barh(classifiers, accuracies, color = 'salmon')
plt.title('Accuracies of each classifiers')
plt.xlabel('Observed accuracy')
plt.ylabel('Classifiers')
plt.show()

# %% [markdown]
# The above bar graph shows that the highest accuracy is given by Logistic Regression, followed by Naive Bayes, Random Forest, Decision Tree, KNN and SVM.

# %% [markdown]
# # Applying Hyper Parameter Tunning for KNN

# %%
k_values = [1,2,3,4,5,6,7]
accuracies = []
for k in k_values:
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    accuracies.append(accuracy_score(y_test, y_pred))

# %%
accuracies
# Out:
# [0.7150837988826816,
#  0.7821229050279329,
#  0.7821229050279329,
#  0.7486033519553073,
#  0.7206703910614525,
#  0.7094972067039106,
#  0.7206703910614525]

# %%
#plotting k values versus accuracy
plt.figure(figsize=(4,4))
plt.plot(k_values, accuracies, color = 'red', linestyle = 'dashed',
        marker = '*', markerfacecolor = 'blue')
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.show()
