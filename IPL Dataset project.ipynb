# %%
# importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ipl = pd.read_csv('matches.csv')
ipl
# Out:
#       id  season       city      date                        team1  \
# 0      1    2017  Hyderabad  5/4/2017          Sunrisers Hyderabad
# 1      2    2017       Pune  6/4/2017               Mumbai Indians
# 2      3    2017     Rajkot  7/4/2017                Gujarat Lions
# 3      4    2017     Indore  8/4/2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  8/4/2017  Royal Challengers Bangalore
# ..   ...     ...        ...       ...                          ...
# 631  632    2016     Raipur  22/05/16             Delhi Daredevils
# 632  633    2016  Bangalore  24/05/16                Gujarat Lions
# 633  634    2016      Delhi  25/05/16          Sunrisers Hyderabad
# 634  635    2016      Delhi  27/05/16                Gujarat Lions
# 635  636    2016  Bangalore  29/05/16          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
# Display the first few rows 
ipl.head()
# Out:
#    id  season       city      date                        team1  \
# 0   1    2017  Hyderabad  5/4/2017          Sunrisers Hyderabad
# 1   2    2017       Pune  6/4/2017               Mumbai Indians
# 2   3    2017     Rajkot  7/4/2017                Gujarat Lions
# 3   4    2017     Indore  8/4/2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  8/4/2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
# Display last few rows
ipl.tail()
# Out:
#       id  season       city      date                team1  \
# 631  632    2016     Raipur  22/05/16     Delhi Daredevils
# 632  633    2016  Bangalore  24/05/16        Gujarat Lions
# 633  634    2016      Delhi  25/05/16  Sunrisers Hyderabad
# 634  635    2016      Delhi  27/05/16        Gujarat Lions
# 635  636    2016  Bangalore  29/05/16  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
# Check the dimesnsions of the dataset
ipl.shape
# Out:
# (636, 18)

# %%
# It gives information or summary 
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
# Get summary statistics of numerical variables
ipl.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
# Check the datatypes of variables
ipl.dtypes
# Out:
# id                   int64
# season               int64
# city                object
# date                object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# result              object
# dl_applied           int64
# winner              object
# win_by_runs          int64
# win_by_wickets       int64
# player_of_match     object
# venue               object
# umpire1             object
# umpire2             object
# umpire3            float64
# dtype: object

# %%
# Check for null values
ipl.isna().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %%
# Filling missing values using mode
ipl['city'].fillna('Mumbai',inplace = True)

# %%
ipl['winner'].fillna('Mumbai Indians',inplace=True)

# %%
ipl['player_of_match'].fillna('CH Gayle',inplace=True)

# %%
ipl['umpire1'].fillna('HDPK Dharmasena',inplace=True)

# %%
ipl['umpire2'].fillna('SJA Taufel',inplace=True)

# %%
# Drop the umpire3 column as it has more null values
ipl.drop('umpire3',axis=1,inplace=True)

# %%
# getting the most man of the match awards
ipl['player_of_match'].value_counts()
# Out:
# player_of_match
# CH Gayle          21
# YK Pathan         16
# DA Warner         15
# AB de Villiers    15
# RG Sharma         14
#                   ..
# AD Mathews         1
# LR Shukla          1
# R Bhatia           1
# A Singh            1
# BCJ Cutting        1
# Name: count, Length: 201, dtype: int64

# %%
# finding number of times each team won the toss
ipl['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: count, dtype: int64

# %%
# looking at number of matches played each season
ipl['season'].value_counts()
# Out:
# season
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: count, dtype: int64

# %%
# Finding out how many times a team won the match after winning the toss
np.sum(ipl['toss_winner'] == ipl['winner'])
# Out:
# 325

# %%
# Top 5 players with most Mom's
ipl['player_of_match'].value_counts()[:5].plot(kind ='barh')
plt.xlabel('Count')
plt.ylabel('Players')
plt.title('Player of the Match')
plt.show()

# %%
# Top 10 players with most Mom's
plt.figure(figsize=(15,7))
plt.bar((ipl['player_of_match'].value_counts().index[:10]), (ipl['player_of_match'].value_counts()[:10]), color = 'maroon')
plt.xlabel('Players')
plt.ylabel('Count')
plt.title('Player of the Match')
plt.show()

# %% [markdown]
# Chris Gayle won most Man of the Match Awards.

# %%
# Getting frequencies of result column
ipl['result'].value_counts()
# Out:
# result
# normal       626
# tie            7
# no result      3
# Name: count, dtype: int64

# %%
plt.bar((ipl['result'].value_counts().index), ipl['result'].value_counts(), color='green')
plt.show()

# %% [markdown]
# There were more Normal Result compared with the other two.

# %%
# Number of matches played in each season
plt.figure(figsize=(15,7))
sns.countplot(x='season',
              data=ipl,
              order = ipl['season'].value_counts().index.sort_values()
              )
plt.xlabel('Season')
plt.ylabel('No of matches')
plt.title('Number of matches played in each IPL season')
plt.show()

# %% [markdown]
# Most number of matches were played in IPL-2013 Season.

# %%
# Matches won by the teams
plt.figure(figsize=(15,7))
sns.countplot(y='winner',
              data=ipl,
              order = ipl['winner'].value_counts().index.sort_values()
              )
plt.xlabel('Team')
plt.ylabel('No. of wins')
plt.title('Matches won by the Teams')
plt.show()

# %% [markdown]
# Mumbai Indians won most number of matches followed by Chennai Super Kings.

# %%
# Number of matches played in stadium, Top 10
plt.figure(figsize = (12,8))
sns.countplot(y = 'venue',
              data = ipl,
              order = ipl['venue'].value_counts().iloc[:10].index,
              palette='gist_heat')
plt.xlabel('No of matches')
plt.ylabel('Venue')
plt.title('Number of matches played in each Stadium')
plt.show()

# %% [markdown]
# Most number of ipl matches were played in M Chinnaswamy Stadium, Banglore.

# %%
toss_dec = ipl.toss_decision.value_counts()
toss_dec
# Out:
# toss_decision
# field    363
# bat      273
# Name: count, dtype: int64

# %%
plt.pie(toss_dec.values, labels = toss_dec.index, autopct='%1.1f%%', shadow=True, explode=(0.1,0.1),
       colors = ['red','pink'],
       wedgeprops={'edgecolor':'black',
                  'linewidth': 2})
plt.title('Teams to choose Bat or Field in Percentage')
plt.legend()
plt.show()

# %% [markdown]
# In more than 57% of matches, teams chose to field after winning the toss.

# %%
win = ipl.winner.value_counts()
win
# Out:
# winner
# Mumbai Indians                 95
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
plt.pie(win.values[:8], labels=win.index[:8], autopct='%1.1f%%')
plt.show()

# %% [markdown]
# The winning percentage of Mumbai Indians is higher followed by Chennai Super Kings.

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='season',
              hue='toss_decision',
              data=ipl,
              order = ipl['season'].value_counts().index.sort_values(),
              palette='deep')
plt.xlabel('Season',fontsize=12)
plt.ylabel('Count',fontsize=12)
plt.title('Decision to field or bat in each IPL season', fontsize=16)
plt.show()

# %% [markdown]
# We can see a trend that, decisions to field are more from IPL-2016 Season

# %%
# Subsetting the matches where the team won batting first
batting_first = ipl[ipl['win_by_runs'] !=0]

# %%
plt.hist(batting_first['win_by_runs'])
plt.title("Distribution of Runs")
plt.xlabel("Runs")
plt.show()

# %%
ipl.hist(figsize=(12,12))
plt.show()

# %%
plt.boxplot(ipl['win_by_runs'])
plt.show()
