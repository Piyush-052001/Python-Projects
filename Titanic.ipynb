# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tit = pd.read_csv('titanicc.csv')
tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tit.shape
# Out:
# (891, 12)

# %%
tit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
tit.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Finding null values
tit.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Deleting the column cabin as it has more null values
tit = tit.drop('Cabin', axis = 1)

# %%
tit.shape
# Out:
# (891, 11)

# %%
tit['Age'].fillna(np.mean(tit.Age), inplace = True)

# %%
tit.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
tit['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# Replacing null values with mode in embarked column
tit['Embarked'].fillna('S', inplace = True)

# %%
tit.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
# Check for duplicates
tit.duplicated().sum()
# Out:
# 0

# %%
print(f' The average age of Titanic passenger is {np.mean(tit.Age)}')
# Out:
#  The average age of Titanic passenger is 29.69911764705882

# %%
print(f' The average fare of Titanic journey is ${np.mean(tit.Fare)}')
# Out:
#  The average fare of Titanic journey is $32.204207968574636

# %%
tit['Age'].hist()
plt.show()

# %%
tit.hist('Fare')
plt.show()

# %%
tit.boxplot('Age')
plt.show()

# %%
tit.boxplot('Fare')
plt.show()

# %%
pass_count = tit.Sex.value_counts()
pass_count
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
plt.bar(pass_count.index, pass_count.values)
plt.xlabel('Gender')
plt.ylabel('Passenger count')
plt.title('Sex Representation')
plt.show()

# %%
# Count the number of passenger in each class
p_class_count = tit.Pclass.value_counts()

# %%
p_class_count
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
plt.bar(p_class_count.index, p_class_count.values, color = 'red', width = 0.5)
plt.xlabel('Passenger Class')
plt.ylabel('Number of passenger')
plt.show()

# %%
count_life = tit.Survived.value_counts()
count_life
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
plt.pie(count_life.values, labels = count_life.index, autopct='%1.1f%%', shadow = True, explode = (0.1,0.1), 
        colors =['red','yellow'], 
        wedgeprops = {'edgecolor' : 'black',
                     'linewidth' : 2})
plt.legend()
plt.show()

# %%
# Finding how many male and female survived
sns.set_style('whitegrid')
sns.countplot(x = 'Survived' , hue ='Sex', data = tit)
plt.show()

# %%
# Finding how many male and female survived from a particular class
sns.set_style('darkgrid')
sns.countplot(x = 'Survived' , hue ='Pclass', data = tit)
plt.show()

# %%
plt.scatter(tit.Age, tit.Fare)
plt.xlabel('Age of passenger')
plt.ylabel('Fare of Ticket')
plt.show()
